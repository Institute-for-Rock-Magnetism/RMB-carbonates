# %%
import pmagpy.ipmag as ipmag
import pmagpy.contribution_builder as cb
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

IRMdb_path = '../data/IRM_DB_export'
MagIC_export_path = '../data/MagIC'

# %%
IRDdb_MagIC_file = IRMdb_path + '/RMB_carbonates.txt'
ipmag.unpack_magic(IRDdb_MagIC_file, dir_path=IRMdb_path)
# Out:
# working on:  'specimens\r'
# 8  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/specimens.txt
#   data put in  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/specimens.txt
# working on:  'samples\r'
# 2  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/samples.txt
#   data put in  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/samples.txt
# working on:  'sites\r'
# 1  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/sites.txt
#   data put in  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/sites.txt
# working on:  'locations\r'
# 1  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/locations.txt
#   data put in  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/locations.txt
# working on:  'measurements\r'
# 1243  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/measurements.txt
#   data put in  /Users/unimos/0000_Github/RMB-carbonates/data/IRM_DB_export/measurements.txt
# True

# %%
contribution = cb.Contribution(IRMdb_path)
measurements = contribution.tables['measurements'].df
specimens = contribution.tables['specimens'].df
samples = contribution.tables['samples'].df
sites = contribution.tables['sites'].df
locations = contribution.tables['locations'].df
# Out:
# -I- Using online data model
# -I- Getting method codes from earthref.org
# -I- Importing controlled vocabularies from https://earthref.org

# %%
method_codes_unique = measurements['method_codes'].unique()
method_codes = ":".join(method_codes_unique.tolist())
method_codes
# Out:
# 'LP-X:LP-X-T:LP-X-F:LP-ZFC:LP-FC:LP-CW-SIRM:LP-MC:LP-CW-SIRM:LP-MW:LP-MST'

# %%
unique_samples = pd.Series(specimens['sample'].unique())
missing_samples = unique_samples[~unique_samples.isin(samples['sample'])]
new_rows = pd.DataFrame({'sample': missing_samples})
samples = pd.concat([samples, new_rows], ignore_index=True)
samples['citations'] = 'This study'
samples['site'] = 'RMB siderite (FeCO3)'
samples
# Out:
#    azimuth   citations                                     description   dip  \
# 0      NaN  This study  Siderite E48. Sample courtesy of David Turner.  90.0
# 1      NaN  This study                            Brendt Hyde Siderite  90.0
# 2      NaN  This study                                             NaN   NaN
# 3      NaN  This study                                             NaN   NaN
# 4      NaN  This study                                             NaN   NaN
#
#    height  lat  lon                sample                  site
# 0     NaN  NaN  NaN   siderite (Dyar) E48  RMB siderite (FeCO3)
# 1     NaN  NaN  NaN  siderite (Dyar) Hyde  RMB siderite (FeCO3)
# 2     NaN  NaN  NaN    siderite_Dalizi-YP  RMB siderite (FeCO3)
# 3     NaN  NaN  NaN        siderite_Roman  RMB siderite (FeCO3)
# 4     NaN  NaN  NaN          siderite_unk  RMB siderite (FeCO3)

# %%
samples_to_exclude = ["siderite (Dyar) E48", "siderite (Dyar) Hyde"]
specimens = specimens[~specimens["sample"].isin(samples_to_exclude)]
samples = samples[~samples["sample"].isin(samples_to_exclude)]
samples['method_codes'] = 'FS-H'

# %%
specimens
# Out:
#                        aniso_f  aniso_l  aniso_p  aniso_s  \
# specimen name
# siderite_Dalizi-YP-01      NaN      NaN      NaN      NaN
# siderite_Roman-01          NaN      NaN      NaN      NaN
# siderite_unk-01            NaN      NaN      NaN      NaN
# siderite_Roman-01          NaN      NaN      NaN      NaN
# siderite_Roman-01          NaN      NaN      NaN      NaN
# siderite_unk-01            NaN      NaN      NaN      NaN
#
#                        aniso_s_n_measurements  aniso_t  aniso_type  azimuth  \
# specimen name
# siderite_Dalizi-YP-01                     NaN      NaN         NaN      NaN
# siderite_Roman-01                         NaN      NaN         NaN      NaN
# siderite_unk-01                           NaN      NaN         NaN      NaN
# siderite_Roman-01                         NaN      NaN         NaN      NaN
# siderite_Roman-01                         NaN      NaN         NaN      NaN
# siderite_unk-01                           NaN      NaN         NaN      NaN
#
#                         citations  contribution_id  critical_temp  \
# specimen name
# siderite_Dalizi-YP-01  This Study              NaN            NaN
# siderite_Roman-01      This Study              NaN            NaN
# siderite_unk-01        This Study              NaN            NaN
# siderite_Roman-01      This Study              NaN          34.13
# siderite_Roman-01      This Study              NaN          33.19
# siderite_unk-01        This Study              NaN          38.06
#
#                        critical_temp_high  critical_temp_low  \
# specimen name
# siderite_Dalizi-YP-01                 NaN                NaN
# siderite_Roman-01                     NaN                NaN
# siderite_unk-01                       NaN                NaN
# siderite_Roman-01                     NaN                NaN
# siderite_Roman-01                     NaN                NaN
# siderite_unk-01                       NaN                NaN
#
#                        critical_temp_mineral critical_temp_type  \
# specimen name
# siderite_Dalizi-YP-01                    NaN               None
# siderite_Roman-01                        NaN               None
# siderite_unk-01                          NaN               None
# siderite_Roman-01                        NaN               Neel
# siderite_Roman-01                        NaN               Neel
# siderite_unk-01                          NaN               Neel
#
#                                                         description  dip  \
# specimen name
# siderite_Dalizi-YP-01                                          None  NaN
# siderite_Roman-01                                              None  NaN
# siderite_unk-01        mass unknown; arbitrary value of 100 mg used  NaN
# siderite_Roman-01                                            by eye  NaN
# siderite_Roman-01              1st derivative minimum FC, remanence  NaN
# siderite_unk-01                1st derivative minimum FC, remanence  NaN
#
#                        experiments  hyst_bc  hyst_bc_offset  hyst_bcr  \
# specimen name
# siderite_Dalizi-YP-01          NaN      NaN             NaN       NaN
# siderite_Roman-01              NaN      NaN             NaN       NaN
# siderite_unk-01                NaN      NaN             NaN       NaN
# siderite_Roman-01              NaN      NaN             NaN       NaN
# siderite_Roman-01              NaN      NaN             NaN       NaN
# siderite_unk-01                NaN      NaN             NaN       NaN
#
#                        hyst_loop  hyst_mr_mass  hyst_ms_mass  hyst_xhf  igsn  \
# specimen name
# siderite_Dalizi-YP-01        NaN           NaN           NaN       NaN   NaN
# siderite_Roman-01            NaN           NaN           NaN       NaN   NaN
# siderite_unk-01              NaN           NaN           NaN       NaN   NaN
# siderite_Roman-01            NaN           NaN           NaN       NaN   NaN
# siderite_Roman-01            NaN           NaN           NaN       NaN   NaN
# siderite_unk-01              NaN           NaN           NaN       NaN   NaN
#
#                        igsn_parent instrument_codes  meas_orient_phi  \
# specimen name
# siderite_Dalizi-YP-01          NaN             None              NaN
# siderite_Roman-01              NaN             None              NaN
# siderite_unk-01                NaN             None              NaN
# siderite_Roman-01              NaN       IRM-BigRed              NaN
# siderite_Roman-01              NaN       IRM-BigRed              NaN
# siderite_unk-01                NaN      IRM-OldBlue              NaN
#
#                        meas_orient_theta  meas_temp  \
# specimen name
# siderite_Dalizi-YP-01                NaN        NaN
# siderite_Roman-01                    NaN        NaN
# siderite_unk-01                      NaN        NaN
# siderite_Roman-01                    NaN        NaN
# siderite_Roman-01                    NaN        NaN
# siderite_unk-01                      NaN        NaN
#
#                                                             method_codes  \
# specimen name
# siderite_Dalizi-YP-01                                     LP-MASS:LP-VOL
# siderite_Roman-01                                         LP-MASS:LP-VOL
# siderite_unk-01                                           LP-MASS:LP-VOL
# siderite_Roman-01              SM-EYE:LP-X-H:LP-ZFC:LP-ZFC:LP-ZFC:LP-ZFC
# siderite_Roman-01            SM-1DMAX:LP-X-H:LP-ZFC:LP-ZFC:LP-ZFC:LP-ZFC
# siderite_unk-01        SM-1DMAX:LP-FC:LP-ZFC:LP-CW-SIRM:LP-MC:LP-CW-S...
#
#                       mineral_type  rem_hirm_mass  rem_sratio  \
# specimen name
# siderite_Dalizi-YP-01     siderite            NaN         NaN
# siderite_Roman-01         siderite            NaN         NaN
# siderite_unk-01           siderite            NaN         NaN
# siderite_Roman-01             None            NaN         NaN
# siderite_Roman-01             None            NaN         NaN
# siderite_unk-01               None            NaN         NaN
#
#                        rem_sratio_back  rem_sratio_forward result_quality  \
# specimen name
# siderite_Dalizi-YP-01              NaN                 NaN              g
# siderite_Roman-01                  NaN                 NaN              g
# siderite_unk-01                    NaN                 NaN              g
# siderite_Roman-01                  NaN                 NaN           None
# siderite_Roman-01                  NaN                 NaN           None
# siderite_unk-01                    NaN                 NaN           None
#
#                        row_id              sample               specimen  \
# specimen name
# siderite_Dalizi-YP-01     NaN  siderite_Dalizi-YP  siderite_Dalizi-YP-01
# siderite_Roman-01         NaN      siderite_Roman      siderite_Roman-01
# siderite_unk-01           NaN        siderite_unk        siderite_unk-01
# siderite_Roman-01         NaN      siderite_Roman      siderite_Roman-01
# siderite_Roman-01         NaN      siderite_Roman      siderite_Roman-01
# siderite_unk-01           NaN        siderite_unk        siderite_unk-01
#
#                       synthetic_alternatives        volume    weight
# specimen name
# siderite_Dalizi-YP-01     siderite_Dalizi-YP  4.000000e-07  0.001187
# siderite_Roman-01             siderite_Roman  1.000000e-07  0.000144
# siderite_unk-01                 siderite_unk  1.000000e-07  0.000100
# siderite_Roman-01             siderite_Roman           NaN       NaN
# siderite_Roman-01             siderite_Roman           NaN       NaN
# siderite_unk-01                 siderite_unk           NaN       NaN

# %%
locations['location_type'] = 'Laboratory'
locations['geologic_classes'] = 'Not Specified'
locations['lithologies'] = 'Not Specified'
locations['lat_s'] = 44.9753
locations['lat_n'] = 44.9753
locations['lon_w'] = -93.2345
locations['lon_e'] = -93.2345
locations['age'] = 2000
locations['age_unit'] = 'Years AD (+/-)'
sites['lat'] = 44.9753
sites['lon'] = -93.2345
sites['age'] = 2000
sites['age_unit'] = 'Years AD (+/-)'
sites['geologic_classes'] = 'Not Specified'
sites['geologic_types'] = 'Not Specified'
sites['lithologies'] = 'Not Specified'
sites['method_codes'] = method_codes
specimens['mineral_class'] = 'Siderite'
specimens['mineral_type'] = 'Not Specified'

# %%
contribution.tables['measurements'].df = measurements
contribution.tables['specimens'].df = specimens
contribution.tables['samples'].df = samples
contribution.tables['sites'].df = sites
contribution.tables['locations'].df = locations

# %%
contribution.tables['locations'].write_magic_file(dir_path=MagIC_export_path,custom_name = "locations.txt")
contribution.tables['sites'].write_magic_file(dir_path=MagIC_export_path,custom_name = "sites.txt")
contribution.tables['samples'].write_magic_file(dir_path=MagIC_export_path,custom_name = "samples.txt")
contribution.tables['specimens'].write_magic_file(dir_path=MagIC_export_path,custom_name = "specimens.txt")
contribution.tables['measurements'].write_magic_file(dir_path=MagIC_export_path,custom_name = "measurements.txt")
# Out:
# -I- overwriting /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/locations.txt
# -I- 1 records written to locations file
# -I- overwriting /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/sites.txt
# -I- 1 records written to sites file
# -I- overwriting /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/samples.txt
# -I- 3 records written to samples file
# -I- overwriting /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/specimens.txt
# -I- 6 records written to specimens file
# -I- overwriting /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/measurements.txt
# -I- 1243 records written to measurements file
# '/Users/unimos/0000_Github/RMB-carbonates/data/MagIC/measurements.txt'

# %%
ipmag.upload_magic(dir_path=MagIC_export_path,
                   input_dir_path=MagIC_export_path)
# Out:
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/locations.txt file successfully read in
# 1  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/locations.txt written to  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/samples.txt file successfully read in
# 3  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/samples.txt written to  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/specimens.txt file successfully read in
# 6  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/specimens.txt written to  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/sites.txt file successfully read in
# 1  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/sites.txt written to  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/measurements.txt file successfully read in
# -I- dropping these columns: external_database_ids from the /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/measurements.txt table
# 1243  records written to file  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# -I- /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/measurements.txt written to  /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/upload.txt
# Finished preparing upload file: /Users/unimos/0000_Github/RMB-carbonates/data/MagIC/RMB-carbonates_05.May.2025_8.txt
# Validating upload file with public endpoint
# status_code= 200
# ('/Users/unimos/0000_Github/RMB-carbonates/data/MagIC/RMB-carbonates_05.May.2025_8.txt',
#  {'status': True,
#   'validation': {'errors': [], 'warnings': []},
#   'warnings': None},
#  None,
#  None)
